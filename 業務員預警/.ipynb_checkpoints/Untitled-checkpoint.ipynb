# %%
import pandas as pd
df=pd.read_excel(r"C:\Users\ray123\Desktop\業務員預警\JobCrawler\JobCrawler\data\jobs104_20191007_test.xlsx")
df.head()
# Out:
#                          上班地點      上班時段                              公司 其他條件  \
# 0     台北市內湖區瑞光路480號11樓D區富台通訊處  日班，依公司規定         富邦人壽_富台通訊處(核准文號108A01號)  未填寫
# 1   台北市中山區建國北路二段238號3樓(富焱通訊處)  日班，依公司規定         富邦人壽_富焱通訊處(核准文號108A01號)  未填寫
# 2   台北市大安區忠孝東路四段320號7樓(富鑽通訊處)  日班，依公司規定         富邦人壽_富鑽通訊處(核准文號108A01號)  未填寫
# 3   台北市中山區建國北路二段236號9樓(富豪通訊處)        日班         富邦人壽_富豪通訊處(核准文號108A01號)  未填寫
# 4  台北市松山區南京東路五段108號12樓(富誠通訊處)  日班，依公司規定  富邦人壽_富誠通訊處(陳炳謙先生)(核准文號108A01號)  未填寫
#
#   具備證照    出差外派  合併欄位         學歷要求  \
# 0  NaN  無需出差外派   NaN         高中以上
# 1  NaN  無需出差外派   NaN         高中以上
# 2  NaN  無需出差外派   NaN         高中以上
# 3  NaN  無需出差外派   NaN  高中、專科、大學、碩士
# 4  NaN  無需出差外派   NaN         高中以上
#
#                                                 工作內容        工作名稱  ...  \
# 0  1.銷售人身保險商品、客戶經營服務並提供富邦金控整合性金融服務；２.本職缺為業務招攬工作，實...  行銷專員CA(正職)  ...
# 1  工作內容1.銷售人身保險商品、客戶經營服務並提供富邦金控整合性金融服務；2.本職缺為業務招攬...  行銷專員CA(正職)  ...
# 2  1.銷售人身保險商品、客戶經營服務並提供富邦金控整合性金融服務；2.本職缺為業務招攬工作，實...  行銷專員CA(正職)  ...
# 3  1.銷售人身保險商品、客戶經營服務並提供富邦金控整合性金融服務；
# ２.本職缺為業務招攬工作，...  行銷專員CA(正職)  ...
# 4  工作內容1.銷售人身保險商品、客戶經營服務並提供富邦金控整合性金融服務；2.本職缺為業務招攬...  行銷專員CA(正職)  ...
#
#                                                 工作連結  應徵人數 擅長工具 斷詞分析 科系要求  \
# 0  https://www.104.com.tw/job/5jgt8?jobsource=201...  0~5人   不拘  NaN   不拘
# 1  https://www.104.com.tw/job/4i4pb?jobsource=201...  0~5人   不拘  NaN   不拘
# 2  https://www.104.com.tw/job/45m0n?jobsource=201...  0~5人   不拘  NaN   不拘
# 3  https://www.104.com.tw/job/3mz0j?jobsource=201...  0~5人   不拘  NaN   不拘
# 4  https://www.104.com.tw/job/6h4mm?jobsource=201...  0~5人   不拘  NaN   不拘
#
#        管理責任    聯絡人      職務類別                                   語文條件     需求人數
# 0  不需負擔管理責任    劉小姐  保險業務／經紀人                                     不拘       不限
# 1  不需負擔管理責任    朱小姐  保險業務／經紀人                                     不拘   1至10 人
# 2  不需負擔管理責任  林宗崎先生  保險業務／經紀人                                     不拘    1至5 人
# 3  不需負擔管理責任  馮偉祥先生  保險業務／經紀人  中文 -- 聽 /中等、說 /中等、讀 /中等、寫 /中等台語 -- 中等  10至30 人
# 4  不需負擔管理責任  陳炳謙先生  保險業務／經紀人                                     不拘      1 人
#
# [5 rows x 25 columns]

# %%
df=df[df['公司'].apply(lambda x : "富邦" in x)]
df=df[df['工作內容'].apply(lambda x : "銷售" in x)]

# %%
df['公司'].apply(lambda x : "富邦" in x).mean()
# Out:
# 1.0

# %%
df.columns
# Out:
# Index(['上班地點', '上班時段', '公司', '其他條件', '具備證照', '出差外派', '合併欄位', '學歷要求', '工作內容',
#        '工作名稱', '工作待遇', '工作性質', '工作技能', '工作經歷', '工作編號', '工作連結', '應徵人數', '擅長工具',
#        '斷詞分析', '科系要求', '管理責任', '聯絡人', '職務類別', '語文條件', '需求人數'],
#       dtype='object')

# %%
col=['上班地點', '上班時段', '公司', '工作內容','工作名稱', '工作待遇', '工作連結','聯絡人']
df=df[col]

# %%
import re
def work_content(s):
    for e in ["保險業務員兼職人員","理財專員","理財規劃師","理財"]:
        if e in s:
            return False
        else:
            return True    

def work_time(s):
    pattern="\d+:\d+"
    r=re.findall(pattern, s, flags=0)
    if r:
        if (int(r[1].replace(":",""))-int(r[0].replace(":","")))<800:
            return False
        else:
            return True
    else:
        return True

def work_salary(s):
    patern="\d+,*\d+"
    r=re.findall(patern,s)
    if r:
        for n in r:
            if int(n.replace(",",""))>40000:
                return False
        return True
    else:
        return True    
def work_loc(s):
    if "敦化南路一段" in s:
        return False
    else:
        return True
    
def work_com_num(s):
    if '核准文號' in s:
        patern="[\dA-Z]+"
        r=re.findall(patern,s)
        if r:
            if r[0] != "108A01":
                return False
            else:
                return True
        else:
            return True
    else :
        return True

# %%
df["是否違規"]=~(df["工作名稱"].apply(work_content)&df["上班時段"].apply(work_time)&df['工作待遇'].apply(work_salary)&df['上班地點'].apply(work_loc)&df["公司"].apply(work_com_num))

# %%
import numpy as np
df['違規原因']=np.nan
df.loc[~df["工作名稱"].apply(work_content),'違規原因']="工作名稱"
df.loc[~df["上班時段"].apply(work_time),'違規原因']="上班時段錯誤(未滿8小時的時間)"
df.loc[~df['工作待遇'].apply(work_salary),'違規原因']="薪資福利錯誤"
df.loc[~df['上班地點'].apply(work_loc),'違規原因']="上班地點錯誤(總公司)"
df.loc[~df["公司"].apply(work_com_num),'違規原因']="核准文號錯誤"

# %%
df.to_csv("result.csv", encoding='utf_8_sig',index=False)

# %%
df.head()
# Out:
#                          上班地點      上班時段                              公司  \
# 0     台北市內湖區瑞光路480號11樓D區富台通訊處  日班，依公司規定         富邦人壽_富台通訊處(核准文號108A01號)
# 1   台北市中山區建國北路二段238號3樓(富焱通訊處)  日班，依公司規定         富邦人壽_富焱通訊處(核准文號108A01號)
# 2   台北市大安區忠孝東路四段320號7樓(富鑽通訊處)  日班，依公司規定         富邦人壽_富鑽通訊處(核准文號108A01號)
# 3   台北市中山區建國北路二段236號9樓(富豪通訊處)        日班         富邦人壽_富豪通訊處(核准文號108A01號)
# 4  台北市松山區南京東路五段108號12樓(富誠通訊處)  日班，依公司規定  富邦人壽_富誠通訊處(陳炳謙先生)(核准文號108A01號)
#
#                                                 工作內容        工作名稱     工作待遇  \
# 0  1.銷售人身保險商品、客戶經營服務並提供富邦金控整合性金融服務；２.本職缺為業務招攬工作，實...  行銷專員CA(正職)  時薪 150元
# 1  工作內容1.銷售人身保險商品、客戶經營服務並提供富邦金控整合性金融服務；2.本職缺為業務招攬...  行銷專員CA(正職)  時薪 150元
# 2  1.銷售人身保險商品、客戶經營服務並提供富邦金控整合性金融服務；2.本職缺為業務招攬工作，實...  行銷專員CA(正職)  時薪 150元
# 3  1.銷售人身保險商品、客戶經營服務並提供富邦金控整合性金融服務；
# ２.本職缺為業務招攬工作，...  行銷專員CA(正職)  時薪 150元
# 4  工作內容1.銷售人身保險商品、客戶經營服務並提供富邦金控整合性金融服務；2.本職缺為業務招攬...  行銷專員CA(正職)  時薪 150元
#
#                                                 工作連結    聯絡人   是否違規 違規原因
# 0  https://www.104.com.tw/job/5jgt8?jobsource=201...    劉小姐  False  NaN
# 1  https://www.104.com.tw/job/4i4pb?jobsource=201...    朱小姐  False  NaN
# 2  https://www.104.com.tw/job/45m0n?jobsource=201...  林宗崎先生  False  NaN
# 3  https://www.104.com.tw/job/3mz0j?jobsource=201...  馮偉祥先生  False  NaN
# 4  https://www.104.com.tw/job/6h4mm?jobsource=201...  陳炳謙先生  False  NaN
